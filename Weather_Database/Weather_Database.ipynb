# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 769

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=038a60cce1e495770e5abaa95ac0ff77

# %%
city_data = []

# %%
print('Beginning Data Retrieval     ')
print('-----------------------------')

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + '&q=' + city.replace(' ', '+')
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chillicothe
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | san rafael del sur
# Processing Record 4 of Set 1 | zabol
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | mariental
# Processing Record 8 of Set 1 | fairbanks
# Processing Record 9 of Set 1 | benghazi
# Processing Record 10 of Set 1 | megion
# Processing Record 11 of Set 1 | yagodnoye
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | hamilton
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | shenjiamen
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | santa cruz
# Processing Record 22 of Set 1 | dongkan
# Processing Record 23 of Set 1 | broome
# Processing Record 24 of Set 1 | colquechaca
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | port hedland
# Processing Record 27 of Set 1 | erbaa
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | dingle
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | nouadhibou
# Processing Record 35 of Set 1 | temiscaming
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | kijang
# Processing Record 39 of Set 1 | dzaoudzi
# Processing Record 40 of Set 1 | pisco
# Processing Record 41 of Set 1 | yulara
# Processing Record 42 of Set 1 | sao joao da barra
# Processing Record 43 of Set 1 | matara
# Processing Record 44 of Set 1 | sosnovo-ozerskoye
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | plaridel
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | vicar
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | emba
# Processing Record 4 of Set 2 | gravelbourg
# Processing Record 5 of Set 2 | barzas
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | la rioja
# Processing Record 8 of Set 2 | roma
# Processing Record 9 of Set 2 | neuquen
# Processing Record 10 of Set 2 | anadyr
# Processing Record 11 of Set 2 | gweta
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | kieta
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | sisimiut
# Processing Record 16 of Set 2 | shizunai
# Processing Record 17 of Set 2 | pangnirtung
# Processing Record 18 of Set 2 | erzin
# Processing Record 19 of Set 2 | nauta
# Processing Record 20 of Set 2 | taoudenni
# Processing Record 21 of Set 2 | thunder bay
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | inuvik
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | antofagasta
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | plainview
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | vardo
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | tautira
# Processing Record 35 of Set 2 | hualmay
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | viedma
# Processing Record 39 of Set 2 | caravelas
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | chik
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | portland
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | kalmunai
# Processing Record 47 of Set 2 | labytnangi
# Processing Record 48 of Set 2 | progreso
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 3 | karasjok
# Processing Record 2 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | lata
# Processing Record 7 of Set 3 | zhigansk
# Processing Record 8 of Set 3 | loreto
# Processing Record 9 of Set 3 | tiruvottiyur
# City not found. Skipping...
# Processing Record 10 of Set 3 | port alfred
# Processing Record 11 of Set 3 | san borja
# Processing Record 12 of Set 3 | lujiang
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | scarborough
# Processing Record 15 of Set 3 | ambon
# Processing Record 16 of Set 3 | rocha
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | kapit
# Processing Record 19 of Set 3 | tashtyp
# Processing Record 20 of Set 3 | alyangula
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | porto nacional
# Processing Record 23 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 24 of Set 3 | airai
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | sandnessjoen
# Processing Record 27 of Set 3 | chicama
# Processing Record 28 of Set 3 | necochea
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | moranbah
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | coquimbo
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | hameenlinna
# Processing Record 37 of Set 3 | ayaviri
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | mareeba
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | hami
# Processing Record 43 of Set 3 | ko samui
# Processing Record 44 of Set 3 | mata
# Processing Record 45 of Set 3 | praia da vitoria
# Processing Record 46 of Set 3 | betare oya
# Processing Record 47 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 3 | yar-sale
# Processing Record 49 of Set 3 | kajaani
# Processing Record 50 of Set 3 | iracoubo
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | chiredzi
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | maiduguri
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | oranjemund
# Processing Record 8 of Set 4 | pierre
# Processing Record 9 of Set 4 | mount gambier
# Processing Record 10 of Set 4 | port macquarie
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | malanje
# Processing Record 13 of Set 4 | port-gentil
# Processing Record 14 of Set 4 | santa maria
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | buin
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | bodden town
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | ceres
# Processing Record 22 of Set 4 | tiksi
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | scottsboro
# Processing Record 25 of Set 4 | hakkari
# Processing Record 26 of Set 4 | kargasok
# Processing Record 27 of Set 4 | wyndham
# Processing Record 28 of Set 4 | fortuna
# Processing Record 29 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 4 | qasigiannguit
# Processing Record 31 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 4 | palmer
# Processing Record 33 of Set 4 | faya
# Processing Record 34 of Set 4 | poum
# Processing Record 35 of Set 4 | sorland
# Processing Record 36 of Set 4 | aanekoski
# Processing Record 37 of Set 4 | libertador general san martin
# Processing Record 38 of Set 4 | deputatskiy
# Processing Record 39 of Set 4 | saint-pierre
# Processing Record 40 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | melo
# Processing Record 42 of Set 4 | parana
# Processing Record 43 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 44 of Set 4 | bilibino
# Processing Record 45 of Set 4 | sunrise manor
# Processing Record 46 of Set 4 | dryden
# Processing Record 47 of Set 4 | penzance
# Processing Record 48 of Set 4 | sur
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | waddan
# Processing Record 1 of Set 5 | goderich
# Processing Record 2 of Set 5 | ixtapa
# Processing Record 3 of Set 5 | komsomolskiy
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | constantine
# Processing Record 6 of Set 5 | half moon bay
# Processing Record 7 of Set 5 | rio grande
# Processing Record 8 of Set 5 | hermanus
# Processing Record 9 of Set 5 | doha
# Processing Record 10 of Set 5 | tawnat
# City not found. Skipping...
# Processing Record 11 of Set 5 | gigmoto
# Processing Record 12 of Set 5 | pevek
# Processing Record 13 of Set 5 | kollumerland
# City not found. Skipping...
# Processing Record 14 of Set 5 | sept-iles
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | hope
# Processing Record 17 of Set 5 | lloydminster
# Processing Record 18 of Set 5 | paragominas
# Processing Record 19 of Set 5 | soavinandriana
# Processing Record 20 of Set 5 | jiaojiang
# Processing Record 21 of Set 5 | devils lake
# Processing Record 22 of Set 5 | bloomfield
# Processing Record 23 of Set 5 | stratonion
# Processing Record 24 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 5 | sitka
# Processing Record 26 of Set 5 | morondava
# Processing Record 27 of Set 5 | amapa
# Processing Record 28 of Set 5 | camara de lobos
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 5 | beidao
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | provideniya
# Processing Record 33 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 5 | ler
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | souillac
# Processing Record 37 of Set 5 | bainbridge
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | katsuura
# Processing Record 40 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 5 | shimoda
# Processing Record 42 of Set 5 | aranos
# Processing Record 43 of Set 5 | miquelon
# Processing Record 44 of Set 5 | ciudad ojeda
# Processing Record 45 of Set 5 | bay-khaak
# Processing Record 46 of Set 5 | khromtau
# Processing Record 47 of Set 5 | naze
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | mnogovershinnyy
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | tondano
# Processing Record 3 of Set 6 | salalah
# Processing Record 4 of Set 6 | mpwapwa
# Processing Record 5 of Set 6 | taonan
# Processing Record 6 of Set 6 | armidale
# Processing Record 7 of Set 6 | copiapo
# Processing Record 8 of Set 6 | los llanos de aridane
# Processing Record 9 of Set 6 | tuktoyaktuk
# Processing Record 10 of Set 6 | onega
# Processing Record 11 of Set 6 | mae sai
# Processing Record 12 of Set 6 | vao
# Processing Record 13 of Set 6 | westport
# Processing Record 14 of Set 6 | banyo
# Processing Record 15 of Set 6 | kahului
# Processing Record 16 of Set 6 | sungairaya
# Processing Record 17 of Set 6 | feldbach
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | fez
# Processing Record 20 of Set 6 | juegang
# Processing Record 21 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 22 of Set 6 | saint anthony
# Processing Record 23 of Set 6 | ponta do sol
# Processing Record 24 of Set 6 | beisfjord
# Processing Record 25 of Set 6 | impfondo
# Processing Record 26 of Set 6 | cascais
# Processing Record 27 of Set 6 | hajnowka
# Processing Record 28 of Set 6 | alexandria
# Processing Record 29 of Set 6 | puro
# Processing Record 30 of Set 6 | awash
# Processing Record 31 of Set 6 | coihaique
# Processing Record 32 of Set 6 | simao
# Processing Record 33 of Set 6 | oyon
# Processing Record 34 of Set 6 | las vegas
# Processing Record 35 of Set 6 | bethel
# Processing Record 36 of Set 6 | grand gaube
# Processing Record 37 of Set 6 | lehututu
# Processing Record 38 of Set 6 | kununurra
# Processing Record 39 of Set 6 | chapais
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 6 | bengkulu
# Processing Record 43 of Set 6 | almaznyy
# Processing Record 44 of Set 6 | beringovskiy
# Processing Record 45 of Set 6 | gewane
# Processing Record 46 of Set 6 | avera
# Processing Record 47 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 6 | tirukkoyilur
# Processing Record 49 of Set 6 | pili
# Processing Record 50 of Set 6 | atambua
# Processing Record 1 of Set 7 | senador pompeu
# Processing Record 2 of Set 7 | ambilobe
# Processing Record 3 of Set 7 | tadine
# Processing Record 4 of Set 7 | khatanga
# Processing Record 5 of Set 7 | olafsvik
# Processing Record 6 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 7 | boma
# Processing Record 8 of Set 7 | tobermory
# Processing Record 9 of Set 7 | carballo
# Processing Record 10 of Set 7 | yarada
# Processing Record 11 of Set 7 | zalukokoazhe
# Processing Record 12 of Set 7 | vila franca do campo
# Processing Record 13 of Set 7 | panama city
# Processing Record 14 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 7 | great bend
# Processing Record 16 of Set 7 | ilhabela
# Processing Record 17 of Set 7 | tabou
# Processing Record 18 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 7 | sal rei
# Processing Record 20 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 7 | aosta
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | chokurdakh
# Processing Record 24 of Set 7 | safita
# Processing Record 25 of Set 7 | saint-michel-des-saints
# Processing Record 26 of Set 7 | swamimalai
# Processing Record 27 of Set 7 | yen bai
# Processing Record 28 of Set 7 | high level
# Processing Record 29 of Set 7 | mookane
# Processing Record 30 of Set 7 | arrecife
# Processing Record 31 of Set 7 | assiniboia
# Processing Record 32 of Set 7 | lodja
# Processing Record 33 of Set 7 | tommot
# Processing Record 34 of Set 7 | victoria
# Processing Record 35 of Set 7 | yumen
# Processing Record 36 of Set 7 | centralia
# Processing Record 37 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 7 | baykit
# Processing Record 39 of Set 7 | grindavik
# Processing Record 40 of Set 7 | clyde river
# Processing Record 41 of Set 7 | senneterre
# Processing Record 42 of Set 7 | itarare
# Processing Record 43 of Set 7 | izumo
# Processing Record 44 of Set 7 | gobabis
# Processing Record 45 of Set 7 | ola
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | dubai
# Processing Record 48 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 7 | soyo
# Processing Record 50 of Set 7 | praxedis guerrero
# Processing Record 1 of Set 8 | kattivakkam
# Processing Record 2 of Set 8 | upernavik
# Processing Record 3 of Set 8 | china
# Processing Record 4 of Set 8 | tual
# Processing Record 5 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 6 of Set 8 | tumen
# Processing Record 7 of Set 8 | kautokeino
# Processing Record 8 of Set 8 | zemio
# Processing Record 9 of Set 8 | saint-joseph
# Processing Record 10 of Set 8 | choma
# Processing Record 11 of Set 8 | qena
# Processing Record 12 of Set 8 | muros
# Processing Record 13 of Set 8 | eureka
# Processing Record 14 of Set 8 | port blair
# Processing Record 15 of Set 8 | warrington
# Processing Record 16 of Set 8 | camacupa
# Processing Record 17 of Set 8 | ketchikan
# Processing Record 18 of Set 8 | biloela
# Processing Record 19 of Set 8 | srednekolymsk
# Processing Record 20 of Set 8 | georgetown
# Processing Record 21 of Set 8 | margate
# Processing Record 22 of Set 8 | coldingham
# Processing Record 23 of Set 8 | borba
# Processing Record 24 of Set 8 | japura
# Processing Record 25 of Set 8 | bangolo
# Processing Record 26 of Set 8 | lukulu
# Processing Record 27 of Set 8 | sao jose da coroa grande
# Processing Record 28 of Set 8 | vila velha
# Processing Record 29 of Set 8 | dessalines
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | banda aceh
# Processing Record 32 of Set 8 | chokwe
# Processing Record 33 of Set 8 | cantapoy
# Processing Record 34 of Set 8 | barrow
# Processing Record 35 of Set 8 | da lat
# Processing Record 36 of Set 8 | antibes
# Processing Record 37 of Set 8 | nizhneivkino
# Processing Record 38 of Set 8 | wilmington
# Processing Record 39 of Set 8 | nortelandia
# Processing Record 40 of Set 8 | farafangana
# Processing Record 41 of Set 8 | moron
# Processing Record 42 of Set 8 | baoding
# Processing Record 43 of Set 8 | awjilah
# Processing Record 44 of Set 8 | cancun
# Processing Record 45 of Set 8 | oktyabrskiy
# Processing Record 46 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 47 of Set 8 | veraval
# Processing Record 48 of Set 8 | lorengau
# Processing Record 49 of Set 8 | alcains
# Processing Record 50 of Set 8 | itarema
# Processing Record 1 of Set 9 | tougue
# Processing Record 2 of Set 9 | puerto narino
# Processing Record 3 of Set 9 | ukiah
# Processing Record 4 of Set 9 | caluquembe
# Processing Record 5 of Set 9 | nurobod
# Processing Record 6 of Set 9 | beloha
# Processing Record 7 of Set 9 | yamada
# Processing Record 8 of Set 9 | bumba
# Processing Record 9 of Set 9 | marinette
# Processing Record 10 of Set 9 | tamandare
# Processing Record 11 of Set 9 | boyolangu
# Processing Record 12 of Set 9 | basco
# Processing Record 13 of Set 9 | uyar
# Processing Record 14 of Set 9 | santa rosalia
# Processing Record 15 of Set 9 | monster
# Processing Record 16 of Set 9 | axim
# Processing Record 17 of Set 9 | karratha
# Processing Record 18 of Set 9 | dunedin
# Processing Record 19 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 9 | touros
# Processing Record 21 of Set 9 | katangli
# Processing Record 22 of Set 9 | maridi
# Processing Record 23 of Set 9 | port-cartier
# Processing Record 24 of Set 9 | madimba
# Processing Record 25 of Set 9 | abu kamal
# Processing Record 26 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 9 | kepala batas
# Processing Record 28 of Set 9 | hofn
# Processing Record 29 of Set 9 | isla vista
# Processing Record 30 of Set 9 | belmonte
# Processing Record 31 of Set 9 | nosy varika
# Processing Record 32 of Set 9 | puerto vallarta
# Processing Record 33 of Set 9 | corn island
# Processing Record 34 of Set 9 | la ronge
# Processing Record 35 of Set 9 | soe
# Processing Record 36 of Set 9 | chulman
# Processing Record 37 of Set 9 | husainabad
# Processing Record 38 of Set 9 | tambilil
# Processing Record 39 of Set 9 | moose factory
# Processing Record 40 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 41 of Set 9 | attingal
# Processing Record 42 of Set 9 | ormara
# Processing Record 43 of Set 9 | fukue
# Processing Record 44 of Set 9 | marsh harbour
# Processing Record 45 of Set 9 | jalu
# Processing Record 46 of Set 9 | ponta delgada
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 49 of Set 9 | laguna
# Processing Record 50 of Set 9 | verkhnyaya toyma
# Processing Record 1 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 10 | kwinana
# Processing Record 3 of Set 10 | berlevag
# Processing Record 4 of Set 10 | harnosand
# Processing Record 5 of Set 10 | puerto escondido
# Processing Record 6 of Set 10 | rodrigues alves
# Processing Record 7 of Set 10 | sao raimundo das mangabeiras
# Processing Record 8 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 9 of Set 10 | athens
# Processing Record 10 of Set 10 | pouebo
# Processing Record 11 of Set 10 | staryy nadym
# Processing Record 12 of Set 10 | opelika
# Processing Record 13 of Set 10 | yuzhno-kurilsk
# Processing Record 14 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 10 | bandarban
# Processing Record 16 of Set 10 | nagato
# Processing Record 17 of Set 10 | codrington
# Processing Record 18 of Set 10 | cunha
# Processing Record 19 of Set 10 | abu samrah
# Processing Record 20 of Set 10 | mazagao
# Processing Record 21 of Set 10 | nerchinskiy zavod
# Processing Record 22 of Set 10 | mount isa
# Processing Record 23 of Set 10 | mainpuri
# Processing Record 24 of Set 10 | povenets
# Processing Record 25 of Set 10 | ugoofaaru
# Processing Record 26 of Set 10 | teguldet
# Processing Record 27 of Set 10 | lubartow
# Processing Record 28 of Set 10 | klaksvik
# Processing Record 29 of Set 10 | fayetteville
# Processing Record 30 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 10 | yerofey pavlovich
# Processing Record 32 of Set 10 | kroya
# Processing Record 33 of Set 10 | asau
# Processing Record 34 of Set 10 | coolum beach
# Processing Record 35 of Set 10 | iturama
# Processing Record 36 of Set 10 | ust-tsilma
# Processing Record 37 of Set 10 | puerto asis
# Processing Record 38 of Set 10 | nicoya
# Processing Record 39 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 10 | biak
# Processing Record 41 of Set 10 | sambava
# Processing Record 42 of Set 10 | dong hoi
# Processing Record 43 of Set 10 | isangel
# Processing Record 44 of Set 10 | changde
# Processing Record 45 of Set 10 | quatre cocos
# Processing Record 46 of Set 10 | ust-kuyga
# Processing Record 47 of Set 10 | asyut
# Processing Record 48 of Set 10 | prieska
# Processing Record 49 of Set 10 | okahandja
# Processing Record 50 of Set 10 | meulaboh
# Processing Record 1 of Set 11 | ternate
# Processing Record 2 of Set 11 | chase
# Processing Record 3 of Set 11 | manzanillo
# Processing Record 4 of Set 11 | cairns
# Processing Record 5 of Set 11 | hejobaba
# Processing Record 6 of Set 11 | lompoc
# Processing Record 7 of Set 11 | tagusao
# Processing Record 8 of Set 11 | kapra
# Processing Record 9 of Set 11 | kathmandu
# Processing Record 10 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 11 | pandan
# Processing Record 12 of Set 11 | the valley
# Processing Record 13 of Set 11 | poronaysk
# Processing Record 14 of Set 11 | hohhot
# Processing Record 15 of Set 11 | pudozh
# Processing Record 16 of Set 11 | lahat
# Processing Record 17 of Set 11 | hopelchen
# Processing Record 18 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 11 | camopi
# Processing Record 20 of Set 11 | calatayud
# Processing Record 21 of Set 11 | mehamn
# Processing Record 22 of Set 11 | lavumisa
# Processing Record 23 of Set 11 | teahupoo
# Processing Record 24 of Set 11 | loucna nad desnou
# Processing Record 25 of Set 11 | pavilosta
# Processing Record 26 of Set 11 | khuzhir
# Processing Record 27 of Set 11 | bensonville
# Processing Record 28 of Set 11 | acapulco
# Processing Record 29 of Set 11 | naryan-mar
# Processing Record 30 of Set 11 | kasempa
# Processing Record 31 of Set 11 | araouane
# Processing Record 32 of Set 11 | port hardy
# Processing Record 33 of Set 11 | riviere-au-renard
# Processing Record 34 of Set 11 | mbaiki
# Processing Record 35 of Set 11 | aldan
# Processing Record 36 of Set 11 | hella
# Processing Record 37 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 11 | leh
# Processing Record 39 of Set 11 | bongandanga
# Processing Record 40 of Set 11 | san jose
# Processing Record 41 of Set 11 | muheza
# Processing Record 42 of Set 11 | boca do acre
# Processing Record 43 of Set 11 | te anau
# Processing Record 44 of Set 11 | paita
# Processing Record 45 of Set 11 | butia
# Processing Record 46 of Set 11 | tilichiki
# Processing Record 47 of Set 11 | yambio
# Processing Record 48 of Set 11 | prainha
# Processing Record 49 of Set 11 | reconquista
# Processing Record 50 of Set 11 | awbari
# Processing Record 1 of Set 12 | ballina
# Processing Record 2 of Set 12 | wabag
# Processing Record 3 of Set 12 | pacific grove
# Processing Record 4 of Set 12 | conakry
# Processing Record 5 of Set 12 | glens falls
# Processing Record 6 of Set 12 | olmos
# Processing Record 7 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 8 of Set 12 | hambantota
# Processing Record 9 of Set 12 | san carlos de bariloche
# Processing Record 10 of Set 12 | hammerfest
# Processing Record 11 of Set 12 | berga
# Processing Record 12 of Set 12 | san lawrenz
# Processing Record 13 of Set 12 | amantea
# Processing Record 14 of Set 12 | kinkala
# Processing Record 15 of Set 12 | zhezkazgan
# Processing Record 16 of Set 12 | humboldt
# Processing Record 17 of Set 12 | jacareacanga
# Processing Record 18 of Set 12 | berzence
# Processing Record 19 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 12 | fagersta
# Processing Record 21 of Set 12 | cape canaveral
# Processing Record 22 of Set 12 | toamasina
# Processing Record 23 of Set 12 | thinadhoo
# Processing Record 24 of Set 12 | dongning
# Processing Record 25 of Set 12 | jati
# Processing Record 26 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 12 | marquette
# Processing Record 28 of Set 12 | damara
# Processing Record 29 of Set 12 | bijie
# Processing Record 30 of Set 12 | kabanjahe
# Processing Record 31 of Set 12 | colares
# Processing Record 32 of Set 12 | siddipet
# Processing Record 33 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 12 | sinnamary
# Processing Record 35 of Set 12 | shamkhal
# Processing Record 36 of Set 12 | kruisfontein
# Processing Record 37 of Set 12 | vizinga
# Processing Record 38 of Set 12 | pontes e lacerda
# Processing Record 39 of Set 12 | carbonia
# Processing Record 40 of Set 12 | muisne
# Processing Record 41 of Set 12 | kloulklubed
# Processing Record 42 of Set 12 | kushmurun
# Processing Record 43 of Set 12 | bure
# Processing Record 44 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 12 | ulladulla
# Processing Record 46 of Set 12 | binga
# Processing Record 47 of Set 12 | suoyarvi
# Processing Record 48 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 49 of Set 12 | gabane
# Processing Record 50 of Set 12 | jorpeland
# Processing Record 1 of Set 13 | syriam
# Processing Record 2 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 13 | kavaratti
# Processing Record 4 of Set 13 | pontian kecil
# Processing Record 5 of Set 13 | clemencia
# Processing Record 6 of Set 13 | mecca
# Processing Record 7 of Set 13 | maniitsoq
# Processing Record 8 of Set 13 | nabire
# Processing Record 9 of Set 13 | kirovskiy
# Processing Record 10 of Set 13 | lafia
# Processing Record 11 of Set 13 | phayao
# Processing Record 12 of Set 13 | kenai
# Processing Record 13 of Set 13 | flinders
# Processing Record 14 of Set 13 | stuttgart
# Processing Record 15 of Set 13 | bosaso
# Processing Record 16 of Set 13 | port keats
# Processing Record 17 of Set 13 | kushima
# Processing Record 18 of Set 13 | novopokrovka
# Processing Record 19 of Set 13 | doba
# Processing Record 20 of Set 13 | indianola
# Processing Record 21 of Set 13 | havre-saint-pierre
# Processing Record 22 of Set 13 | ucluelet
# Processing Record 23 of Set 13 | fort saint james
# Processing Record 24 of Set 13 | warkworth
# Processing Record 25 of Set 13 | grigiskes
# Processing Record 26 of Set 13 | porto novo
# Processing Record 27 of Set 13 | gondar
# Processing Record 28 of Set 13 | ekuvukeni
# Processing Record 29 of Set 13 | biskamzha
# Processing Record 30 of Set 13 | puerto madryn
# Processing Record 31 of Set 13 | talara
# Processing Record 32 of Set 13 | tinskoy
# Processing Record 33 of Set 13 | udachnyy
# Processing Record 34 of Set 13 | tome
# Processing Record 35 of Set 13 | cururupu
# Processing Record 36 of Set 13 | chirongui
# Processing Record 37 of Set 13 | aklavik
# Processing Record 38 of Set 13 | tecoanapa
# Processing Record 39 of Set 13 | fort-shevchenko
# Processing Record 40 of Set 13 | lincoln
# Processing Record 41 of Set 13 | palauig
# Processing Record 42 of Set 13 | calabazar de sagua
# Processing Record 43 of Set 13 | husavik
# Processing Record 44 of Set 13 | iskateley
# Processing Record 45 of Set 13 | atar
# Processing Record 46 of Set 13 | kitui
# Processing Record 47 of Set 13 | partizanskoye
# Processing Record 48 of Set 13 | dom pedro
# Processing Record 49 of Set 13 | apt
# Processing Record 50 of Set 13 | katherine
# Processing Record 1 of Set 14 | woodstock
# Processing Record 2 of Set 14 | haines junction
# Processing Record 3 of Set 14 | bonga
# Processing Record 4 of Set 14 | bambanglipuro
# Processing Record 5 of Set 14 | najran
# Processing Record 6 of Set 14 | bahia blanca
# Processing Record 7 of Set 14 | hay river
# Processing Record 8 of Set 14 | korla
# Processing Record 9 of Set 14 | elizabeth city
# Processing Record 10 of Set 14 | dauphin
# Processing Record 11 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 14 | kodinar
# Processing Record 13 of Set 14 | raga
# Processing Record 14 of Set 14 | vomp
# Processing Record 15 of Set 14 | burnie
# Processing Record 16 of Set 14 | ajdabiya
# Processing Record 17 of Set 14 | finnsnes
# Processing Record 18 of Set 14 | kailua
# Processing Record 19 of Set 14 | flin flon
# Processing Record 20 of Set 14 | mayo
# Processing Record 21 of Set 14 | hwange
# Processing Record 22 of Set 14 | jiamusi
# Processing Record 23 of Set 14 | abomsa
# Processing Record 24 of Set 14 | nieuwpoort
# Processing Record 25 of Set 14 | estelle
# Processing Record 26 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 14 | myski
# Processing Record 28 of Set 14 | pringsewu
# Processing Record 29 of Set 14 | asamankese
# Processing Record 30 of Set 14 | amahai
# Processing Record 31 of Set 14 | kafue
# Processing Record 32 of Set 14 | walvis bay
# Processing Record 33 of Set 14 | umm lajj
# Processing Record 34 of Set 14 | belz
# Processing Record 35 of Set 14 | kedougou
# Processing Record 36 of Set 14 | waitati
# Processing Record 37 of Set 14 | batemans bay
# Processing Record 38 of Set 14 | vestmanna
# Processing Record 39 of Set 14 | san alejo
# Processing Record 40 of Set 14 | yenagoa
# Processing Record 41 of Set 14 | san patricio
# Processing Record 42 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 14 | monrovia
# Processing Record 44 of Set 14 | toora-khem
# Processing Record 45 of Set 14 | prince rupert
# Processing Record 46 of Set 14 | manoel urbano
# Processing Record 47 of Set 14 | saint-leu
# Processing Record 48 of Set 14 | srandakan
# Processing Record 49 of Set 14 | pangoa
# Processing Record 50 of Set 14 | ishii
# Processing Record 1 of Set 15 | saint-gabriel
# Processing Record 2 of Set 15 | long xuyen
# Processing Record 3 of Set 15 | kindu
# Processing Record 4 of Set 15 | jablah
# Processing Record 5 of Set 15 | cap malheureux
# Processing Record 6 of Set 15 | verkhovyna
# Processing Record 7 of Set 15 | beruwala
# Processing Record 8 of Set 15 | antalaha
# Processing Record 9 of Set 15 | nguruka
# Processing Record 10 of Set 15 | yanam
# Processing Record 11 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 15 | vostok
# Processing Record 13 of Set 15 | mount pleasant
# Processing Record 14 of Set 15 | tahta
# Processing Record 15 of Set 15 | grakhovo
# Processing Record 16 of Set 15 | lundazi
# Processing Record 17 of Set 15 | jining
# Processing Record 18 of Set 15 | raychikhinsk
# Processing Record 19 of Set 15 | nederland
# Processing Record 20 of Set 15 | panguna
# Processing Record 21 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 22 of Set 15 | torres
# Processing Record 23 of Set 15 | laela
# Processing Record 24 of Set 15 | groningen
# Processing Record 25 of Set 15 | gizo
# Processing Record 26 of Set 15 | kurumkan
# Processing Record 27 of Set 15 | kamenka
# Processing Record 28 of Set 15 | vestmannaeyjar
# Processing Record 29 of Set 15 | bolobo
# Processing Record 30 of Set 15 | lithakia
# Processing Record 31 of Set 15 | valdivia
# Processing Record 32 of Set 15 | martinsburg
# Processing Record 33 of Set 15 | peniche
# Processing Record 34 of Set 15 | keuruu
# Processing Record 35 of Set 15 | buraydah
# Processing Record 36 of Set 15 | beira
# Processing Record 37 of Set 15 | mahajanga
# Processing Record 38 of Set 15 | tortoli
# Processing Record 39 of Set 15 | paramonga
# Processing Record 40 of Set 15 | zhangye
# Processing Record 41 of Set 15 | caxias
# Processing Record 42 of Set 15 | krasnokamensk
# Processing Record 43 of Set 15 | gat
# Processing Record 44 of Set 15 | padang
# Processing Record 45 of Set 15 | dodoma
# Processing Record 46 of Set 15 | arcata
# Processing Record 47 of Set 15 | siparia
# Processing Record 48 of Set 15 | shakawe
# Processing Record 49 of Set 15 | natitingou
# Processing Record 50 of Set 15 | mbamba
# Processing Record 1 of Set 16 | atlantic city
# Processing Record 2 of Set 16 | hikone
# Processing Record 3 of Set 16 | arlit
# Processing Record 4 of Set 16 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 16 | sofiyivka
# Processing Record 6 of Set 16 | weligama
# Processing Record 7 of Set 16 | waingapu
# Processing Record 8 of Set 16 | kralendijk
# Processing Record 9 of Set 16 | imbituba
# Processing Record 10 of Set 16 | boueni
# Processing Record 11 of Set 16 | chifeng
# Processing Record 12 of Set 16 | kantunilkin
# Processing Record 13 of Set 16 | royan
# Processing Record 14 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 16 | adjumani
# Processing Record 16 of Set 16 | mackay
# Processing Record 17 of Set 16 | chinchani
# Processing Record 18 of Set 16 | tabora
# Processing Record 19 of Set 16 | mogok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Chillicothe  39.3331  -82.9824     50.00        93           1
# 1               Rikitea -23.1203 -134.9692     79.63        72          62
# 2    San Rafael Del Sur  11.8485  -86.4384     75.20        88          20
# 3                 Zabol  32.2500   67.2500     66.24        22           9
# 4                Avarua -21.2078 -159.7750     78.80        89          20
# ..                  ...      ...       ...       ...       ...         ...
# 706            Adjumani   3.3779   31.7909    100.20        14          97
# 707              Mackay -21.1500  149.2000     75.20        88          40
# 708           Chinchani  19.8667   72.7000     86.02        43           0
# 709              Tabora  -5.0167   32.8000     87.80        42          40
# 710               Mogok  22.9167   96.5000     70.27        26          25
#
#      Wind Speed Country Current Description
# 0          3.58      US           clear sky
# 1         17.07      PF       broken clouds
# 2          6.91      NI          few clouds
# 3         16.98      AF           clear sky
# 4          5.75      CK          few clouds
# ..          ...     ...                 ...
# 706        8.46      UG     overcast clouds
# 707        6.91      AU    scattered clouds
# 708       10.25      IN           clear sky
# 709       11.50      TZ    scattered clouds
# 710        2.66      MM    scattered clouds
#
# [711 rows x 9 columns]

# %%
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Chillicothe      US  39.3331  -82.9824     50.00        93
# 1               Rikitea      PF -23.1203 -134.9692     79.63        72
# 2    San Rafael Del Sur      NI  11.8485  -86.4384     75.20        88
# 3                 Zabol      AF  32.2500   67.2500     66.24        22
# 4                Avarua      CK -21.2078 -159.7750     78.80        89
# ..                  ...     ...      ...       ...       ...       ...
# 706            Adjumani      UG   3.3779   31.7909    100.20        14
# 707              Mackay      AU -21.1500  149.2000     75.20        88
# 708           Chinchani      IN  19.8667   72.7000     86.02        43
# 709              Tabora      TZ  -5.0167   32.8000     87.80        42
# 710               Mogok      MM  22.9167   96.5000     70.27        26
#
#      Cloudiness  Wind Speed Current Description
# 0             1        3.58           clear sky
# 1            62       17.07       broken clouds
# 2            20        6.91          few clouds
# 3             9       16.98           clear sky
# 4            20        5.75          few clouds
# ..          ...         ...                 ...
# 706          97        8.46     overcast clouds
# 707          40        6.91    scattered clouds
# 708           0       10.25           clear sky
# 709          40       11.50    scattered clouds
# 710          25        2.66    scattered clouds
#
# [711 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
